# %%
#W2A1
print("Hello, World")
# Out:
# Hello, World

# %%
#W2A2
name = input("Nhập tên của bạn:")
print("Chào mừng", name, "đã đến với lớp CS1")
# Out:
# Nhập tên của bạn:Nguyễn Hải Nam
# Chào mừng Nguyễn Hải Nam đã đến với lớp CS1

# %%
#W2A3
a,b=map(int,input('Nhập 2 số nguyên:').split())
print('Tổng:',a+b)
print('Hiệu:',a-b)
print('Tích:',a*b)
print('Chia lấy phần nguyên:',a//b)
print('Chia lấy dư:',a%b)
print(f'Thương:{a/b:.2f}')
# Out:
# Nhập 2 số nguyên:8 6
# Tổng: 14
# Hiệu: 2
# Tích: 48
# Chia lấy phần nguyên: 1
# Chia lấy dư: 2
# Thương:1.33

# %%
#W2A4
a_1,b_1,c_1,a_2,b_2,a_3=map(float,input('Nhập điểm: ').split())
print(f'Điểm trung bình: {(a_1+b_1+c_1+(a_2+b_2)*2+a_3*3)/10:.1f}')
# Out:
# Nhập điểm: 7 8 7 8.5 9.25 7
# Điểm trung bình: 7.8

# %%
#W2A5
a,b=map(int,input('Nhập số:').split())
print('Kết quả a mũ b:',a**b)
# Out:
# Nhập số:2 3
# Kết quả a mũ b: 8

# %%
#W2A6
letter=input('Nhập chữ cái: ')
print(ord(letter))
print(ord(letter.upper()))
# Out:
# Nhập chữ cái: a
# 97
# 65

# %%
#W2A7
A=int(((13**2)*3)+5)
print('A =',A)
B=int(13**2*3+5)
print('B =',B)
# Out:
# A = 512
# B = 512

# %%
#W2A8
C=float(input('Nhập nhiệt độ C: '))
print(f'Nhiệt độ F là: {(9/5) * C+32:.2f}')
# Out:
# Nhập nhiệt độ C: 30
# Nhiệt độ F là: 86.00

# %%
#W2A9
x=float(input('Giá tiền của đồng hồ (theo đơn vị USD):'))
print(f'Tổng tiền phải trả là: {10+x*(1+0.1+0.3):.2f} USD')
# Out:
# Giá tiền của đồng hồ (theo đơn vị USD):757
# Tổng tiền phải trả là: 1069.80 USD

# %%
#W2A10
list = input("Nhập tên của 3 bạn: ").split()
list.reverse()
print(list[0], list[1], list[2])
# Out:
# Nhập tên của 3 bạn: Nam Hùng Cường
# Cường Hùng Nam

# %%
#W2A11
hour,minute=map(int,input('Nhập số giờ và phút: ').split())
hour_to_second=hour*3600
minute_to_second=minute*60
print(f'Tổng số giây trong {hour} giờ là: {hour_to_second} giây')
print(f'Tổng số giây trong {minute} phút là: {minute_to_second} giây')
# Out:
# Nhập số giờ và phút: 2 50
# Tổng số giây trong 2 giờ là: 7200 giây
# Tổng số giây trong 50 phút là: 3000 giây

# %%
#W2A12
n=int(input('Độ dài 1 cạnh của khối rubik: '))
print('Số miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương là:', 6*n**2)
# Out:
# Độ dài 1 cạnh của khối rubik: 3
# Số miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương là: 54

# %%
#W2A13
a,b=map(int,input('Nhập 2 số a,b: ').split())
print('Giá trị hàng đơn vị của tích a*b là:', str(a*b)[-1:])
# Out:
# Nhập 2 số a,b: 43 56
# Giá trị hàng đơn vị của tích a*b là: 8

# %%
#W2A14
numbers=input('Nhập lần lượt 2 số a và b: ').split()
numbers.reverse()
print('a =',numbers[0],', b =',numbers[1])
# Out:
# Nhập lần lượt 2 số a và b: 3 5
# a = 5 , b = 3

# %%
#W2A15
n=int(input('Nhập số nguyên dương n: '))
rule=1+6*n*(n-1)
print('Hình thứ',n,'có số sao là:',rule)
# Out:
# Nhập số nguyên dương n: 3
# Hình thứ 3 có số sao là: 37

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
for i in range(1,6,2):
  print("*"*i)
# Out:
# *
# ***
# *****

# %%
#W2A18
print("### ##   ### ###")
print(" #  # #   #   # ")
print(" #  #  #  #   # ")
print(" #  # #   #   # ")
print(" #  ##    #   # ")
# Out:
# ### ##   ### ###
#  #  # #   #   #
#  #  #  #  #   #
#  #  # #   #   #
#  #  ##    #   #

# %%
#W2A19
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
  print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
